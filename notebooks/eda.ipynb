# %%
# %pip install wfdb matplotlib

import wfdb
import matplotlib.pyplot as plt

# Download record 100 from MIT-BIH
record = wfdb.rdrecord('100', pn_dir='mitdb')  # Requires internet access
wfdb.plot_wfdb(record=record, title='MIT-BIH ECG Signal')

print("Signal shape:", record.p_signal.shape)
print("Sampling frequency:", record.fs)
print("Channels:", record.sig_name)
# Out:
# ...
# Matplotlib is building the font cache; this may take a moment.
# Signal shape: (650000, 2)
# Sampling frequency: 360
# Channels: ['MLII', 'V5']
